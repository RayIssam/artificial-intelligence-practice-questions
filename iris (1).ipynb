# %%
'''
Please develop different classification models with respect to different feature couples. For instance, your first model will take sepal_length and sepal_width as the input, the second one would be using any other two features… You should have 6 different models. Please report your results for the test and train datasets separately for these 6 models. Hint: Your results might be similar but just for the following features when chosen together: sepal_length and sepal_width.
'''
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# Load the iris dataset
iris = load_iris()
X, y = iris.data, iris.target
feature_names = iris.feature_names

# Define feature combinations
feature_combinations = [
    (0, 1),  # sepal_length and sepal_width
    (0, 2),  # sepal_length and petal_length
    (0, 3),  # sepal_length and petal_width
    (1, 2),  # sepal_width and petal_length
    (1, 3),  # sepal_width and petal_width
    (2, 3)   # petal_length and petal_width
]

# Define classifiers
classifiers = {
    "SVM": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier()
}

# List to collect results
results = []

# Train and test each classifier on each feature combination
for i, (f1, f2) in enumerate(feature_combinations, 1):
    # Prepare feature subset
    X_subset = X[:, [f1, f2]]

    # Split data
    X_train, X_test, y_train, y_test = train_test_split(X_subset, y, test_size=0.2, random_state=42)

    for name, clf in classifiers.items():
        # Train model
        clf.fit(X_train, y_train)

        # Evaluate on training and test sets
        train_acc = accuracy_score(y_train, clf.predict(X_train))
        test_acc = accuracy_score(y_test, clf.predict(X_test))

        # Append results
        results.append({
            "Feature Pair": f"{feature_names[f1]}, {feature_names[f2]}",
            "Classifier": name,
            "Train Accuracy": train_acc,
            "Test Accuracy": test_acc
        })

# Convert results to DataFrame and display
results_df = pd.DataFrame(results)
print(results_df)
# Out:
#                             Feature Pair     Classifier  Train Accuracy  \
# 0    sepal length (cm), sepal width (cm)            SVM        0.783333
# 1    sepal length (cm), sepal width (cm)  Decision Tree        0.941667
# 2    sepal length (cm), sepal width (cm)  Random Forest        0.941667
# 3   sepal length (cm), petal length (cm)            SVM        0.958333
# 4   sepal length (cm), petal length (cm)  Decision Tree        0.991667
# 5   sepal length (cm), petal length (cm)  Random Forest        0.991667
# 6    sepal length (cm), petal width (cm)            SVM        0.950000
# 7    sepal length (cm), petal width (cm)  Decision Tree        0.975000
# 8    sepal length (cm), petal width (cm)  Random Forest        0.975000
# 9    sepal width (cm), petal length (cm)            SVM        0.950000
# 10   sepal width (cm), petal length (cm)  Decision Tree        0.991667
# 11   sepal width (cm), petal length (cm)  Random Forest        0.991667
# ...

# %%
'''
Please work on the dimensionality reduction example for the iris dataset. Please increase the component number from 2 to 3. Then make the visualizations for all of the component couples. There will be three different combinations: C1-C2, C1-C3, and C2-C3. Please write your observations briefly especially when you compare these outputs with the pairplot given above (figure above).
Resource for learning : https://jakevdp.github.io/PythonDataScienceHandbook/05.02-introducing-scikit-learn.html#Unsupervised-learning-example:-Iris-dimensionality
'''
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# Load the iris dataset
iris = load_iris()
X, y = iris.data, iris.target
feature_names = iris.feature_names

# Define feature combinations
feature_combinations = [
    (0, 1),  # sepal_length and sepal_width
    (0, 2),  # sepal_length and petal_length
    (0, 3),  # sepal_length and petal_width
    (1, 2),  # sepal_width and petal_length
    (1, 3),  # sepal_width and petal_width
    (2, 3)   # petal_length and petal_width
]

# Define classifiers
classifiers = {
    "SVM": SVC(),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier()
}

# List to collect results
results = []

# Train and test each classifier on each feature combination
for i, (f1, f2) in enumerate(feature_combinations, 1):
    # Prepare feature subset
    X_subset = X[:, [f1, f2]]

    # Split data
    X_train, X_test, y_train, y_test = train_test_split(X_subset, y, test_size=0.2, random_state=42)

    for name, clf in classifiers.items():
        # Train model
        clf.fit(X_train, y_train)

        # Evaluate on training and test sets
        train_acc = accuracy_score(y_train, clf.predict(X_train))
        test_acc = accuracy_score(y_test, clf.predict(X_test))

        # Append results
        results.append({
            "Feature Pair": f"{feature_names[f1]}, {feature_names[f2]}",
            "Classifier": name,
            "Train Accuracy": train_acc,
            "Test Accuracy": test_acc
        })

# Convert results to DataFrame
results_df = pd.DataFrame(results)

# Find the best feature pair and classifier based on highest test accuracy
best_result = results_df.loc[results_df['Test Accuracy'].idxmax()]
best_feature_pair = best_result['Feature Pair']
best_classifier = best_result['Classifier']
best_test_accuracy = best_result['Test Accuracy']

# Print the DataFrame and the best result
print("All Results:")
print(results_df)
print("\nBest Feature Pair and Classifier:")
print(f"Feature Pair: {best_feature_pair}")
print(f"Classifier: {best_classifier}")
print(f"Test Accuracy: {best_test_accuracy:.2f}")
# Out:
# All Results:
#                             Feature Pair     Classifier  Train Accuracy  \
# 0    sepal length (cm), sepal width (cm)            SVM        0.783333
# 1    sepal length (cm), sepal width (cm)  Decision Tree        0.941667
# 2    sepal length (cm), sepal width (cm)  Random Forest        0.941667
# 3   sepal length (cm), petal length (cm)            SVM        0.958333
# 4   sepal length (cm), petal length (cm)  Decision Tree        0.991667
# 5   sepal length (cm), petal length (cm)  Random Forest        0.991667
# 6    sepal length (cm), petal width (cm)            SVM        0.950000
# 7    sepal length (cm), petal width (cm)  Decision Tree        0.975000
# 8    sepal length (cm), petal width (cm)  Random Forest        0.975000
# 9    sepal width (cm), petal length (cm)            SVM        0.950000
# 10   sepal width (cm), petal length (cm)  Decision Tree        0.991667
# 11   sepal width (cm), petal length (cm)  Random Forest        0.991667
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# Load the Iris dataset and create a DataFrame
iris = load_iris()
X_iris = iris.data
y_iris = iris.target
target_names = iris.target_names

# Perform PCA with 3 components
pca = PCA(n_components=3)
X_pca = pca.fit_transform(X_iris)

# Create a DataFrame for easier plotting
iris_pca_df = pd.DataFrame(X_pca, columns=["Component 1", "Component 2", "Component 3"])
iris_pca_df['Species'] = y_iris

# Set up the figure for the three component pairs: C1-C2, C1-C3, and C2-C3
plt.figure(figsize=(18, 5))

# Plot C1 vs C2
plt.subplot(1, 3, 1)
sns.scatterplot(x="Component 1", y="Component 2", hue="Species", data=iris_pca_df, palette="viridis", s=60)
plt.title("Component 1 vs Component 2")
plt.xlabel("Component 1")
plt.ylabel("Component 2")

# Plot C1 vs C3
plt.subplot(1, 3, 2)
sns.scatterplot(x="Component 1", y="Component 3", hue="Species", data=iris_pca_df, palette="viridis", s=60)
plt.title("Component 1 vs Component 3")
plt.xlabel("Component 1")
plt.ylabel("Component 3")

# Plot C2 vs C3
plt.subplot(1, 3, 3)
sns.scatterplot(x="Component 2", y="Component 3", hue="Species", data=iris_pca_df, palette="viridis", s=60)
plt.title("Component 2 vs Component 3")
plt.xlabel("Component 2")
plt.ylabel("Component 3")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture

# Load the Iris dataset
iris_data = load_iris()
X_iris = iris_data.data
y_iris = iris_data.target

# Perform PCA to reduce the data to 2 components for visualization purposes
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_iris)

# Create a DataFrame with PCA results and species information
iris_df = pd.DataFrame(X_pca, columns=["PCA1", "PCA2"])
iris_df['species'] = y_iris

# Define the number of clusters to try with GMM
cluster_counts = [2, 3, 4, 5]

# Set up the plotting area
fig, axes = plt.subplots(1, len(cluster_counts), figsize=(20, 5), sharey=True)

# Apply GMM with different cluster counts and plot the results
for i, n_clusters in enumerate(cluster_counts):
    # 1. Instantiate and fit the GMM model
    model = GaussianMixture(n_components=n_clusters, covariance_type='full', random_state=42)
    model.fit(X_iris)

    # 2. Predict cluster assignments
    iris_df['cluster'] = model.predict(X_iris)

    # 3. Plot the results for each cluster count
    sns.scatterplot(x="PCA1", y="PCA2", hue="cluster", data=iris_df, ax=axes[i], palette="viridis", s=60)
    axes[i].set_title(f"GMM with {n_clusters} Clusters")
    axes[i].set_xlabel("PCA1")
    axes[i].set_ylabel("PCA2")

plt.tight_layout()
plt.show()
