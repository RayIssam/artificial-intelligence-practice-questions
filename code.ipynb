# %%
import os
import shutil
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torch.cuda.amp import GradScaler, autocast
import numpy as np
from PIL import Image
import csv
import zipfile
from google.colab import files

# CIFAR-10 Class Names
CIFAR10_CLASSES = [
    "airplane", "automobile", "bird", "cat", "deer",
    "dog", "frog", "horse", "ship", "truck"
]

# Define the device globally
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# Log results to a CSV file
def log_results(topology, lr, accuracy, class_accuracies, output_file='results.csv'):
    with open(output_file, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([str(topology), lr, accuracy] + class_accuracies)

# Load full CIFAR-10 dataset
def load_cifar10_full(batch_size=128):
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    # Load full training and test sets
    trainset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
    testset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

    # Create DataLoaders
    trainloader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2, pin_memory=True)
    testloader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=True)
    return trainloader, testloader

# Define a dynamic neural network model
class CIFAR10Model(nn.Module):
    def __init__(self, topology):
        super(CIFAR10Model, self).__init__()
        layers = []
        input_size = 3072  # CIFAR-10 flattened input size (32x32x3)
        for size in topology:
            layers.append(nn.Linear(input_size, size))
            layers.append(nn.ReLU())
            input_size = size
        layers.pop()  # Remove the last ReLU for the output layer
        self.network = nn.Sequential(*layers)

    def forward(self, x):
        x = x.view(x.size(0), -1)  # Flatten input
        return self.network(x)

# Create folders to save true and false predictions
def create_output_folders(base_dir='output'):
    true_dir = os.path.join(base_dir, 'true')
    false_dir = os.path.join(base_dir, 'false')
    shutil.rmtree(base_dir, ignore_errors=True)  # Remove old folders if they exist
    os.makedirs(true_dir, exist_ok=True)
    os.makedirs(false_dir, exist_ok=True)
    return true_dir, false_dir

# Save misclassified and correctly classified images
def save_image(image, folder, filename):
    if not os.path.exists(folder):
        os.makedirs(folder)
    image = image.squeeze().permute(1, 2, 0).numpy()  # Convert to HWC format
    image = (image * 255).astype('uint8')  # Rescale to 0-255
    img = Image.fromarray(image)
    img.save(os.path.join(folder, filename))

# Train and evaluate the model
def train_and_evaluate_model(topology, learning_rate, epochs=50, batch_size=128, base_dir='output'):
    trainloader, testloader = load_cifar10_full(batch_size=batch_size)

    # Define the model and move it to the global device
    model = CIFAR10Model(topology).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    scaler = GradScaler()  # For mixed precision training

    # Training loop
    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        for images, labels in trainloader:
            images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)

            optimizer.zero_grad()
            with autocast():
                outputs = model(images)
                loss = criterion(outputs, labels)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            running_loss += loss.item()

        print(f"Epoch {epoch+1}/{epochs}, Loss: {running_loss/len(trainloader):.4f}")

    # Evaluation loop and saving images
    model.eval()
    true_dir, false_dir = create_output_folders(base_dir)
    correct = 0
    total = 0
    class_correct = [0] * 10  # To track correct predictions for each class
    class_total = [0] * 10    # To track total images for each class
    with torch.no_grad():
        for i, (images, labels) in enumerate(testloader):
            images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            # Calculate class-wise accuracy
            for idx in range(len(images)):
                label = labels[idx]
                is_correct = (predicted[idx] == label).item()
                class_total[label] += 1
                class_correct[label] += is_correct

                # Save images
                folder = true_dir if is_correct else false_dir
                filename = f'image_{i * len(images) + idx}.png'
                save_image(images[idx].cpu(), folder, filename)

    accuracy = 100 * correct / total
    print(f"Test Accuracy: {accuracy:.2f}%")

    # Class-wise accuracy
    class_accuracies = []
    for i in range(10):
        class_accuracy = 100 * class_correct[i] / class_total[i] if class_total[i] > 0 else 0
        print(f"Accuracy of {CIFAR10_CLASSES[i]}: {class_accuracy:.2f}%")
        class_accuracies.append(class_accuracy)

    print(f"Saved images to '{base_dir}/true' (correct) and '{base_dir}/false' (incorrect')")

    return accuracy, class_accuracies

# Zip the output folder for downloading
def zip_output_folder(folder_name='output', zip_name='output.zip'):
    with zipfile.ZipFile(zip_name, 'w') as zipf:
        for root, dirs, files in os.walk(folder_name):
            for file in files:
                file_path = os.path.join(root, file)
                zipf.write(file_path, os.path.relpath(file_path, folder_name))
    print(f"Zipped folder '{folder_name}' into '{zip_name}'")

# Main training and logging
with open('results.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Topology', 'Learning Rate', 'Accuracy', 'Plane Accuracy', 'Car Accuracy', 'Bird Accuracy',
                     'Cat Accuracy', 'Deer Accuracy', 'Dog Accuracy', 'Frog Accuracy', 'Horse Accuracy', 'Ship Accuracy', 'Truck Accuracy'])

topologies = [
    [1024, 128, 10],
    [1024, 128, 256, 10],
    [1024, 128, 256, 256, 10],
    [1024, 128, 256, 256, 128, 10],
    [1024, 128, 256, 512, 256, 10],
    [1024, 128, 256, 512, 256, 128, 10],
    [1024, 128, 256, 512, 1024, 512, 256, 10],
    [1024, 128, 256, 512, 1024, 512, 256, 128, 10],
    [1024, 128, 256, 512, 1024, 2048, 1024, 512, 256, 128, 10],
    [1024, 128, 256, 512, 1024, 512, 1024, 256, 128, 10]
]

learning_rates = [0.001, 0.005]

for lr in learning_rates:
    for topology in topologies:
        print(f"Training topology: {topology} with learning rate: {lr}")
        accuracy, class_accuracies = train_and_evaluate_model(topology, learning_rate=lr, epochs=50, base_dir='output')
        log_results(topology, lr, accuracy, class_accuracies)

# Zip the output folder after training
zip_output_folder()

# If using Google Colab, provide a download link
files.download('output.zip')
# Out:
# Using device: cuda
# Training topology: [1024, 128, 10] with learning rate: 0.001
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:13<00:00, 12.7MB/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# <ipython-input-1-8b3625ba0b14>:90: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()  # For mixed precision training
# <ipython-input-1-8b3625ba0b14>:100: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 1/50, Loss: 1.6333
# Epoch 2/50, Loss: 1.4224
# Epoch 3/50, Loss: 1.3063
# Epoch 4/50, Loss: 1.2222
# Epoch 5/50, Loss: 1.1378
# Epoch 6/50, Loss: 1.0588
# Epoch 7/50, Loss: 0.9858
# Epoch 8/50, Loss: 0.9109
# Epoch 9/50, Loss: 0.8394
# Epoch 10/50, Loss: 0.7711
# Epoch 11/50, Loss: 0.7081
# Epoch 12/50, Loss: 0.6444
# Epoch 13/50, Loss: 0.5896
# Epoch 14/50, Loss: 0.5370
# Epoch 15/50, Loss: 0.4991
# Epoch 16/50, Loss: 0.4570
# Epoch 17/50, Loss: 0.4292
# Epoch 18/50, Loss: 0.3864
# Epoch 19/50, Loss: 0.3755
# Epoch 20/50, Loss: 0.3507
# Epoch 21/50, Loss: 0.3362
# Epoch 22/50, Loss: 0.3087
# Epoch 23/50, Loss: 0.2856
# Epoch 24/50, Loss: 0.2707
# Epoch 25/50, Loss: 0.2687
# Epoch 26/50, Loss: 0.2548
# Epoch 27/50, Loss: 0.2540
# Epoch 28/50, Loss: 0.2263
# Epoch 29/50, Loss: 0.2394
# Epoch 30/50, Loss: 0.2267
# Epoch 31/50, Loss: 0.2107
# Epoch 32/50, Loss: 0.2018
# Epoch 33/50, Loss: 0.2043
# Epoch 34/50, Loss: 0.2002
# Epoch 35/50, Loss: 0.1947
# Epoch 36/50, Loss: 0.1863
# Epoch 37/50, Loss: 0.1893
# Epoch 38/50, Loss: 0.1827
# Epoch 39/50, Loss: 0.1739
# Epoch 40/50, Loss: 0.1577
# Epoch 41/50, Loss: 0.1788
# Epoch 42/50, Loss: 0.1662
# Epoch 43/50, Loss: 0.1554
# Epoch 44/50, Loss: 0.1597
# Epoch 45/50, Loss: 0.1707
# Epoch 46/50, Loss: 0.1418
# Epoch 47/50, Loss: 0.1472
# Epoch 48/50, Loss: 0.1444
# Epoch 49/50, Loss: 0.1446
# Epoch 50/50, Loss: 0.1380
# Test Accuracy: 53.19%
# Accuracy of airplane: 60.20%
# Accuracy of automobile: 65.40%
# Accuracy of bird: 39.40%
# Accuracy of cat: 41.70%
# Accuracy of deer: 46.70%
# Accuracy of dog: 40.30%
# Accuracy of frog: 54.50%
# Accuracy of horse: 59.50%
# Accuracy of ship: 68.10%
# Accuracy of truck: 56.10%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 10] with learning rate: 0.001
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.6535
# Epoch 2/50, Loss: 1.4331
# Epoch 3/50, Loss: 1.3115
# Epoch 4/50, Loss: 1.2180
# Epoch 5/50, Loss: 1.1391
# Epoch 6/50, Loss: 1.0557
# Epoch 7/50, Loss: 0.9844
# Epoch 8/50, Loss: 0.9201
# Epoch 9/50, Loss: 0.8505
# Epoch 10/50, Loss: 0.7844
# Epoch 11/50, Loss: 0.7222
# Epoch 12/50, Loss: 0.6595
# Epoch 13/50, Loss: 0.6099
# Epoch 14/50, Loss: 0.5557
# Epoch 15/50, Loss: 0.5147
# Epoch 16/50, Loss: 0.4873
# Epoch 17/50, Loss: 0.4501
# Epoch 18/50, Loss: 0.4143
# Epoch 19/50, Loss: 0.3980
# Epoch 20/50, Loss: 0.3672
# Epoch 21/50, Loss: 0.3426
# Epoch 22/50, Loss: 0.3326
# Epoch 23/50, Loss: 0.3156
# Epoch 24/50, Loss: 0.2980
# Epoch 25/50, Loss: 0.2911
# Epoch 26/50, Loss: 0.2800
# Epoch 27/50, Loss: 0.2634
# Epoch 28/50, Loss: 0.2579
# Epoch 29/50, Loss: 0.2635
# Epoch 30/50, Loss: 0.2399
# Epoch 31/50, Loss: 0.2315
# Epoch 32/50, Loss: 0.2264
# Epoch 33/50, Loss: 0.2335
# Epoch 34/50, Loss: 0.2358
# Epoch 35/50, Loss: 0.2070
# Epoch 36/50, Loss: 0.1988
# Epoch 37/50, Loss: 0.2093
# Epoch 38/50, Loss: 0.1948
# Epoch 39/50, Loss: 0.1979
# Epoch 40/50, Loss: 0.1863
# Epoch 41/50, Loss: 0.2114
# Epoch 42/50, Loss: 0.1817
# Epoch 43/50, Loss: 0.1633
# Epoch 44/50, Loss: 0.1875
# Epoch 45/50, Loss: 0.1745
# Epoch 46/50, Loss: 0.1812
# Epoch 47/50, Loss: 0.1798
# Epoch 48/50, Loss: 0.1634
# Epoch 49/50, Loss: 0.1837
# Epoch 50/50, Loss: 0.1532
# Test Accuracy: 53.34%
# Accuracy of airplane: 61.80%
# Accuracy of automobile: 63.80%
# Accuracy of bird: 39.40%
# Accuracy of cat: 43.10%
# Accuracy of deer: 38.20%
# Accuracy of dog: 41.00%
# Accuracy of frog: 56.10%
# Accuracy of horse: 61.20%
# Accuracy of ship: 68.50%
# Accuracy of truck: 60.30%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 256, 10] with learning rate: 0.001
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.6810
# Epoch 2/50, Loss: 1.4534
# Epoch 3/50, Loss: 1.3341
# Epoch 4/50, Loss: 1.2325
# Epoch 5/50, Loss: 1.1532
# Epoch 6/50, Loss: 1.0740
# Epoch 7/50, Loss: 1.0006
# Epoch 8/50, Loss: 0.9240
# Epoch 9/50, Loss: 0.8581
# Epoch 10/50, Loss: 0.7877
# Epoch 11/50, Loss: 0.7307
# Epoch 12/50, Loss: 0.6812
# Epoch 13/50, Loss: 0.6299
# Epoch 14/50, Loss: 0.5741
# Epoch 15/50, Loss: 0.5335
# Epoch 16/50, Loss: 0.4976
# Epoch 17/50, Loss: 0.4656
# Epoch 18/50, Loss: 0.4343
# Epoch 19/50, Loss: 0.4076
# Epoch 20/50, Loss: 0.3894
# Epoch 21/50, Loss: 0.3621
# Epoch 22/50, Loss: 0.3424
# Epoch 23/50, Loss: 0.3278
# Epoch 24/50, Loss: 0.3117
# Epoch 25/50, Loss: 0.3048
# Epoch 26/50, Loss: 0.2928
# Epoch 27/50, Loss: 0.2773
# Epoch 28/50, Loss: 0.2591
# Epoch 29/50, Loss: 0.2654
# Epoch 30/50, Loss: 0.2380
# Epoch 31/50, Loss: 0.2347
# Epoch 32/50, Loss: 0.2424
# Epoch 33/50, Loss: 0.2221
# Epoch 34/50, Loss: 0.2279
# Epoch 35/50, Loss: 0.2152
# Epoch 36/50, Loss: 0.2138
# Epoch 37/50, Loss: 0.1973
# Epoch 38/50, Loss: 0.2097
# Epoch 39/50, Loss: 0.1917
# Epoch 40/50, Loss: 0.1956
# Epoch 41/50, Loss: 0.1956
# Epoch 42/50, Loss: 0.1819
# Epoch 43/50, Loss: 0.1951
# Epoch 44/50, Loss: 0.1776
# Epoch 45/50, Loss: 0.1812
# Epoch 46/50, Loss: 0.1639
# Epoch 47/50, Loss: 0.1718
# Epoch 48/50, Loss: 0.1646
# Epoch 49/50, Loss: 0.1639
# Epoch 50/50, Loss: 0.1614
# Test Accuracy: 54.15%
# Accuracy of airplane: 64.20%
# Accuracy of automobile: 60.10%
# Accuracy of bird: 40.80%
# Accuracy of cat: 44.30%
# Accuracy of deer: 48.90%
# Accuracy of dog: 38.60%
# Accuracy of frog: 58.60%
# Accuracy of horse: 62.20%
# Accuracy of ship: 67.50%
# Accuracy of truck: 56.30%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 256, 128, 10] with learning rate: 0.001
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.7139
# Epoch 2/50, Loss: 1.4787
# Epoch 3/50, Loss: 1.3529
# Epoch 4/50, Loss: 1.2523
# Epoch 5/50, Loss: 1.1705
# Epoch 6/50, Loss: 1.0951
# Epoch 7/50, Loss: 1.0174
# Epoch 8/50, Loss: 0.9491
# Epoch 9/50, Loss: 0.8789
# Epoch 10/50, Loss: 0.8170
# Epoch 11/50, Loss: 0.7562
# Epoch 12/50, Loss: 0.7011
# Epoch 13/50, Loss: 0.6509
# Epoch 14/50, Loss: 0.6014
# Epoch 15/50, Loss: 0.5577
# Epoch 16/50, Loss: 0.5155
# Epoch 17/50, Loss: 0.4767
# Epoch 18/50, Loss: 0.4479
# Epoch 19/50, Loss: 0.4259
# Epoch 20/50, Loss: 0.3920
# Epoch 21/50, Loss: 0.3730
# Epoch 22/50, Loss: 0.3474
# Epoch 23/50, Loss: 0.3300
# Epoch 24/50, Loss: 0.3241
# Epoch 25/50, Loss: 0.3065
# Epoch 26/50, Loss: 0.2821
# Epoch 27/50, Loss: 0.2847
# Epoch 28/50, Loss: 0.2717
# Epoch 29/50, Loss: 0.2541
# Epoch 30/50, Loss: 0.2454
# Epoch 31/50, Loss: 0.2386
# Epoch 32/50, Loss: 0.2278
# Epoch 33/50, Loss: 0.2369
# Epoch 34/50, Loss: 0.2254
# Epoch 35/50, Loss: 0.2140
# Epoch 36/50, Loss: 0.2057
# Epoch 37/50, Loss: 0.2037
# Epoch 38/50, Loss: 0.1806
# Epoch 39/50, Loss: 0.1956
# Epoch 40/50, Loss: 0.1865
# Epoch 41/50, Loss: 0.1910
# Epoch 42/50, Loss: 0.1802
# Epoch 43/50, Loss: 0.1714
# Epoch 44/50, Loss: 0.1704
# Epoch 45/50, Loss: 0.1732
# Epoch 46/50, Loss: 0.1634
# Epoch 47/50, Loss: 0.1601
# Epoch 48/50, Loss: 0.1608
# Epoch 49/50, Loss: 0.1635
# Epoch 50/50, Loss: 0.1540
# Test Accuracy: 54.18%
# Accuracy of airplane: 58.50%
# Accuracy of automobile: 62.20%
# Accuracy of bird: 38.70%
# Accuracy of cat: 34.40%
# Accuracy of deer: 44.80%
# Accuracy of dog: 47.90%
# Accuracy of frog: 62.00%
# Accuracy of horse: 57.60%
# Accuracy of ship: 73.90%
# Accuracy of truck: 61.80%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 512, 256, 10] with learning rate: 0.001
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.7117
# Epoch 2/50, Loss: 1.4763
# Epoch 3/50, Loss: 1.3596
# Epoch 4/50, Loss: 1.2602
# Epoch 5/50, Loss: 1.1795
# Epoch 6/50, Loss: 1.1028
# Epoch 7/50, Loss: 1.0280
# Epoch 8/50, Loss: 0.9614
# Epoch 9/50, Loss: 0.8963
# Epoch 10/50, Loss: 0.8360
# Epoch 11/50, Loss: 0.7795
# Epoch 12/50, Loss: 0.7269
# Epoch 13/50, Loss: 0.6731
# Epoch 14/50, Loss: 0.6289
# Epoch 15/50, Loss: 0.5892
# Epoch 16/50, Loss: 0.5548
# Epoch 17/50, Loss: 0.5154
# Epoch 18/50, Loss: 0.4759
# Epoch 19/50, Loss: 0.4498
# Epoch 20/50, Loss: 0.4336
# Epoch 21/50, Loss: 0.4065
# Epoch 22/50, Loss: 0.3776
# Epoch 23/50, Loss: 0.3657
# Epoch 24/50, Loss: 0.3431
# Epoch 25/50, Loss: 0.3310
# Epoch 26/50, Loss: 0.3064
# Epoch 27/50, Loss: 0.2997
# Epoch 28/50, Loss: 0.2957
# Epoch 29/50, Loss: 0.2819
# Epoch 30/50, Loss: 0.2718
# Epoch 31/50, Loss: 0.2604
# Epoch 32/50, Loss: 0.2640
# Epoch 33/50, Loss: 0.2459
# Epoch 34/50, Loss: 0.2423
# Epoch 35/50, Loss: 0.2302
# Epoch 36/50, Loss: 0.2301
# Epoch 37/50, Loss: 0.2175
# Epoch 38/50, Loss: 0.2080
# Epoch 39/50, Loss: 0.2110
# Epoch 40/50, Loss: 0.2046
# Epoch 41/50, Loss: 0.2005
# Epoch 42/50, Loss: 0.2007
# Epoch 43/50, Loss: 0.1891
# Epoch 44/50, Loss: 0.1887
# Epoch 45/50, Loss: 0.1848
# Epoch 46/50, Loss: 0.1723
# Epoch 47/50, Loss: 0.1796
# Epoch 48/50, Loss: 0.1801
# Epoch 49/50, Loss: 0.1627
# Epoch 50/50, Loss: 0.1682
# Test Accuracy: 54.22%
# Accuracy of airplane: 64.20%
# Accuracy of automobile: 61.20%
# Accuracy of bird: 45.90%
# Accuracy of cat: 44.60%
# Accuracy of deer: 40.40%
# Accuracy of dog: 40.90%
# Accuracy of frog: 57.80%
# Accuracy of horse: 59.00%
# Accuracy of ship: 68.90%
# Accuracy of truck: 59.30%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 512, 256, 128, 10] with learning rate: 0.001
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.7508
# Epoch 2/50, Loss: 1.5095
# Epoch 3/50, Loss: 1.3859
# Epoch 4/50, Loss: 1.2879
# Epoch 5/50, Loss: 1.2092
# Epoch 6/50, Loss: 1.1299
# Epoch 7/50, Loss: 1.0577
# Epoch 8/50, Loss: 0.9887
# Epoch 9/50, Loss: 0.9224
# Epoch 10/50, Loss: 0.8626
# Epoch 11/50, Loss: 0.7998
# Epoch 12/50, Loss: 0.7452
# Epoch 13/50, Loss: 0.6894
# Epoch 14/50, Loss: 0.6472
# Epoch 15/50, Loss: 0.6008
# Epoch 16/50, Loss: 0.5601
# Epoch 17/50, Loss: 0.5333
# Epoch 18/50, Loss: 0.5000
# Epoch 19/50, Loss: 0.4718
# Epoch 20/50, Loss: 0.4358
# Epoch 21/50, Loss: 0.4114
# Epoch 22/50, Loss: 0.3972
# Epoch 23/50, Loss: 0.3754
# Epoch 24/50, Loss: 0.3380
# Epoch 25/50, Loss: 0.3358
# Epoch 26/50, Loss: 0.3106
# Epoch 27/50, Loss: 0.3088
# Epoch 28/50, Loss: 0.2970
# Epoch 29/50, Loss: 0.2874
# Epoch 30/50, Loss: 0.2753
# Epoch 31/50, Loss: 0.2573
# Epoch 32/50, Loss: 0.2528
# Epoch 33/50, Loss: 0.2447
# Epoch 34/50, Loss: 0.2326
# Epoch 35/50, Loss: 0.2295
# Epoch 36/50, Loss: 0.2266
# Epoch 37/50, Loss: 0.2151
# Epoch 38/50, Loss: 0.2026
# Epoch 39/50, Loss: 0.2057
# Epoch 40/50, Loss: 0.1960
# Epoch 41/50, Loss: 0.1886
# Epoch 42/50, Loss: 0.1818
# Epoch 43/50, Loss: 0.1877
# Epoch 44/50, Loss: 0.1817
# Epoch 45/50, Loss: 0.1763
# Epoch 46/50, Loss: 0.1753
# Epoch 47/50, Loss: 0.1689
# Epoch 48/50, Loss: 0.1776
# Epoch 49/50, Loss: 0.1653
# Epoch 50/50, Loss: 0.1576
# Test Accuracy: 53.28%
# Accuracy of airplane: 63.70%
# Accuracy of automobile: 60.80%
# Accuracy of bird: 44.80%
# Accuracy of cat: 30.90%
# Accuracy of deer: 36.30%
# Accuracy of dog: 50.90%
# Accuracy of frog: 62.10%
# Accuracy of horse: 59.50%
# Accuracy of ship: 61.90%
# Accuracy of truck: 61.90%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 512, 1024, 512, 256, 10] with learning rate: 0.001
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.7992
# Epoch 2/50, Loss: 1.5654
# Epoch 3/50, Loss: 1.4388
# Epoch 4/50, Loss: 1.3372
# Epoch 5/50, Loss: 1.2606
# Epoch 6/50, Loss: 1.1886
# Epoch 7/50, Loss: 1.1231
# Epoch 8/50, Loss: 1.0561
# Epoch 9/50, Loss: 1.0002
# Epoch 10/50, Loss: 0.9419
# Epoch 11/50, Loss: 0.8843
# Epoch 12/50, Loss: 0.8329
# Epoch 13/50, Loss: 0.7837
# Epoch 14/50, Loss: 0.7391
# Epoch 15/50, Loss: 0.7007
# Epoch 16/50, Loss: 0.6649
# Epoch 17/50, Loss: 0.6269
# Epoch 18/50, Loss: 0.5921
# Epoch 19/50, Loss: 0.5591
# Epoch 20/50, Loss: 0.5341
# Epoch 21/50, Loss: 0.5092
# Epoch 22/50, Loss: 0.4871
# Epoch 23/50, Loss: 0.4495
# Epoch 24/50, Loss: 0.4466
# Epoch 25/50, Loss: 0.4231
# Epoch 26/50, Loss: 0.4003
# Epoch 27/50, Loss: 0.3796
# Epoch 28/50, Loss: 0.3778
# Epoch 29/50, Loss: 0.3575
# Epoch 30/50, Loss: 0.3386
# Epoch 31/50, Loss: 0.3372
# Epoch 32/50, Loss: 0.3141
# Epoch 33/50, Loss: 0.3086
# Epoch 34/50, Loss: 0.2978
# Epoch 35/50, Loss: 0.2880
# Epoch 36/50, Loss: 0.2831
# Epoch 37/50, Loss: 0.2654
# Epoch 38/50, Loss: 0.2648
# Epoch 39/50, Loss: 0.2529
# Epoch 40/50, Loss: 0.2435
# Epoch 41/50, Loss: 0.2374
# Epoch 42/50, Loss: 0.2315
# Epoch 43/50, Loss: 0.2368
# Epoch 44/50, Loss: 0.2206
# Epoch 45/50, Loss: 0.2123
# Epoch 46/50, Loss: 0.2095
# Epoch 47/50, Loss: 0.2037
# Epoch 48/50, Loss: 0.2041
# Epoch 49/50, Loss: 0.2097
# Epoch 50/50, Loss: 0.2002
# Test Accuracy: 53.31%
# Accuracy of airplane: 61.50%
# Accuracy of automobile: 65.60%
# Accuracy of bird: 38.20%
# Accuracy of cat: 36.50%
# Accuracy of deer: 39.70%
# Accuracy of dog: 48.70%
# Accuracy of frog: 58.60%
# Accuracy of horse: 60.90%
# Accuracy of ship: 65.40%
# Accuracy of truck: 58.00%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 512, 1024, 512, 256, 128, 10] with learning rate: 0.001
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.8737
# Epoch 2/50, Loss: 1.6484
# Epoch 3/50, Loss: 1.5088
# Epoch 4/50, Loss: 1.4073
# Epoch 5/50, Loss: 1.3184
# Epoch 6/50, Loss: 1.2536
# Epoch 7/50, Loss: 1.1794
# Epoch 8/50, Loss: 1.1188
# Epoch 9/50, Loss: 1.0505
# Epoch 10/50, Loss: 0.9972
# Epoch 11/50, Loss: 0.9461
# Epoch 12/50, Loss: 0.8850
# Epoch 13/50, Loss: 0.8439
# Epoch 14/50, Loss: 0.7933
# Epoch 15/50, Loss: 0.7527
# Epoch 16/50, Loss: 0.7146
# Epoch 17/50, Loss: 0.6756
# Epoch 18/50, Loss: 0.6338
# Epoch 19/50, Loss: 0.6068
# Epoch 20/50, Loss: 0.5899
# Epoch 21/50, Loss: 0.5498
# Epoch 22/50, Loss: 0.5279
# Epoch 23/50, Loss: 0.5010
# Epoch 24/50, Loss: 0.4739
# Epoch 25/50, Loss: 0.4632
# Epoch 26/50, Loss: 0.4428
# Epoch 27/50, Loss: 0.4303
# Epoch 28/50, Loss: 0.4032
# Epoch 29/50, Loss: 0.3886
# Epoch 30/50, Loss: 0.3795
# Epoch 31/50, Loss: 0.3598
# Epoch 32/50, Loss: 0.3454
# Epoch 33/50, Loss: 0.3329
# Epoch 34/50, Loss: 0.3211
# Epoch 35/50, Loss: 0.3168
# Epoch 36/50, Loss: 0.3069
# Epoch 37/50, Loss: 0.3131
# Epoch 38/50, Loss: 0.2829
# Epoch 39/50, Loss: 0.2802
# Epoch 40/50, Loss: 0.2663
# Epoch 41/50, Loss: 0.2624
# Epoch 42/50, Loss: 0.2612
# Epoch 43/50, Loss: 0.2351
# Epoch 44/50, Loss: 0.2472
# Epoch 45/50, Loss: 0.2347
# Epoch 46/50, Loss: 0.2279
# Epoch 47/50, Loss: 0.2167
# Epoch 48/50, Loss: 0.2251
# Epoch 49/50, Loss: 0.2156
# Epoch 50/50, Loss: 0.2101
# Test Accuracy: 53.69%
# Accuracy of airplane: 58.10%
# Accuracy of automobile: 65.80%
# Accuracy of bird: 41.00%
# Accuracy of cat: 39.20%
# Accuracy of deer: 45.30%
# Accuracy of dog: 43.90%
# Accuracy of frog: 57.20%
# Accuracy of horse: 58.50%
# Accuracy of ship: 69.60%
# Accuracy of truck: 58.30%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 512, 1024, 2048, 1024, 512, 256, 128, 10] with learning rate: 0.001
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 2.0226
# Epoch 2/50, Loss: 1.8905
# Epoch 3/50, Loss: 1.7048
# Epoch 4/50, Loss: 1.5818
# Epoch 5/50, Loss: 1.4741
# Epoch 6/50, Loss: 1.3822
# Epoch 7/50, Loss: 1.3062
# Epoch 8/50, Loss: 1.2380
# Epoch 9/50, Loss: 1.1701
# Epoch 10/50, Loss: 1.1100
# Epoch 11/50, Loss: 1.0533
# Epoch 12/50, Loss: 0.9963
# Epoch 13/50, Loss: 0.9494
# Epoch 14/50, Loss: 0.9015
# Epoch 15/50, Loss: 0.8543
# Epoch 16/50, Loss: 0.8176
# Epoch 17/50, Loss: 0.7679
# Epoch 18/50, Loss: 0.7530
# Epoch 19/50, Loss: 0.7128
# Epoch 20/50, Loss: 0.6693
# Epoch 21/50, Loss: 0.6522
# Epoch 22/50, Loss: 0.6199
# Epoch 23/50, Loss: 0.5913
# Epoch 24/50, Loss: 0.5699
# Epoch 25/50, Loss: 0.5473
# Epoch 26/50, Loss: 0.5245
# Epoch 27/50, Loss: 0.5092
# Epoch 28/50, Loss: 0.4926
# Epoch 29/50, Loss: 0.4771
# Epoch 30/50, Loss: 0.4505
# Epoch 31/50, Loss: 0.4346
# Epoch 32/50, Loss: 0.4216
# Epoch 33/50, Loss: 0.4007
# Epoch 34/50, Loss: 0.3979
# Epoch 35/50, Loss: 0.3817
# Epoch 36/50, Loss: 0.3624
# Epoch 37/50, Loss: 0.3531
# Epoch 38/50, Loss: 0.3373
# Epoch 39/50, Loss: 0.3305
# Epoch 40/50, Loss: 0.3317
# Epoch 41/50, Loss: 0.3144
# Epoch 42/50, Loss: 0.3026
# Epoch 43/50, Loss: 0.3031
# Epoch 44/50, Loss: 0.2993
# Epoch 45/50, Loss: 0.2904
# Epoch 46/50, Loss: 0.2795
# Epoch 47/50, Loss: 0.2711
# Epoch 48/50, Loss: 0.2675
# Epoch 49/50, Loss: 0.2400
# Epoch 50/50, Loss: 0.2447
# Test Accuracy: 52.46%
# Accuracy of airplane: 64.90%
# Accuracy of automobile: 63.20%
# Accuracy of bird: 37.80%
# Accuracy of cat: 33.00%
# Accuracy of deer: 45.50%
# Accuracy of dog: 43.40%
# Accuracy of frog: 55.70%
# Accuracy of horse: 61.50%
# Accuracy of ship: 63.40%
# Accuracy of truck: 56.20%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 512, 1024, 512, 1024, 256, 128, 10] with learning rate: 0.001
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.9539
# Epoch 2/50, Loss: 1.7291
# Epoch 3/50, Loss: 1.5849
# Epoch 4/50, Loss: 1.4679
# Epoch 5/50, Loss: 1.3776
# Epoch 6/50, Loss: 1.2922
# Epoch 7/50, Loss: 1.2267
# Epoch 8/50, Loss: 1.1662
# Epoch 9/50, Loss: 1.1083
# Epoch 10/50, Loss: 1.0512
# Epoch 11/50, Loss: 0.9997
# Epoch 12/50, Loss: 0.9494
# Epoch 13/50, Loss: 0.9004
# Epoch 14/50, Loss: 0.8543
# Epoch 15/50, Loss: 0.8075
# Epoch 16/50, Loss: 0.7665
# Epoch 17/50, Loss: 0.7377
# Epoch 18/50, Loss: 0.6978
# Epoch 19/50, Loss: 0.6669
# Epoch 20/50, Loss: 0.6383
# Epoch 21/50, Loss: 0.6097
# Epoch 22/50, Loss: 0.5903
# Epoch 23/50, Loss: 0.5575
# Epoch 24/50, Loss: 0.5394
# Epoch 25/50, Loss: 0.5190
# Epoch 26/50, Loss: 0.4916
# Epoch 27/50, Loss: 0.4708
# Epoch 28/50, Loss: 0.4648
# Epoch 29/50, Loss: 0.4400
# Epoch 30/50, Loss: 0.4212
# Epoch 31/50, Loss: 0.4093
# Epoch 32/50, Loss: 0.3895
# Epoch 33/50, Loss: 0.3800
# Epoch 34/50, Loss: 0.3667
# Epoch 35/50, Loss: 0.3602
# Epoch 36/50, Loss: 0.3396
# Epoch 37/50, Loss: 0.3430
# Epoch 38/50, Loss: 0.3271
# Epoch 39/50, Loss: 0.3109
# Epoch 40/50, Loss: 0.3109
# Epoch 41/50, Loss: 0.2904
# Epoch 42/50, Loss: 0.2878
# Epoch 43/50, Loss: 0.2800
# Epoch 44/50, Loss: 0.2763
# Epoch 45/50, Loss: 0.2596
# Epoch 46/50, Loss: 0.2483
# Epoch 47/50, Loss: 0.2478
# Epoch 48/50, Loss: 0.2513
# Epoch 49/50, Loss: 0.2441
# Epoch 50/50, Loss: 0.2331
# Test Accuracy: 53.90%
# Accuracy of airplane: 69.40%
# Accuracy of automobile: 66.20%
# Accuracy of bird: 40.20%
# Accuracy of cat: 39.40%
# Accuracy of deer: 42.20%
# Accuracy of dog: 45.80%
# Accuracy of frog: 58.40%
# Accuracy of horse: 56.60%
# Accuracy of ship: 65.20%
# Accuracy of truck: 55.60%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 10] with learning rate: 0.005
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.8406
# Epoch 2/50, Loss: 1.6557
# Epoch 3/50, Loss: 1.5790
# Epoch 4/50, Loss: 1.5221
# Epoch 5/50, Loss: 1.4721
# Epoch 6/50, Loss: 1.4393
# Epoch 7/50, Loss: 1.4060
# Epoch 8/50, Loss: 1.3695
# Epoch 9/50, Loss: 1.3206
# Epoch 10/50, Loss: 1.2898
# Epoch 11/50, Loss: 1.2639
# Epoch 12/50, Loss: 1.2415
# Epoch 13/50, Loss: 1.2047
# Epoch 14/50, Loss: 1.1790
# Epoch 15/50, Loss: 1.1554
# Epoch 16/50, Loss: 1.1308
# Epoch 17/50, Loss: 1.1298
# Epoch 18/50, Loss: 1.1047
# Epoch 19/50, Loss: 1.0922
# Epoch 20/50, Loss: 1.0723
# Epoch 21/50, Loss: 1.0331
# Epoch 22/50, Loss: 1.0453
# Epoch 23/50, Loss: 1.0462
# Epoch 24/50, Loss: 1.0247
# Epoch 25/50, Loss: 1.0150
# Epoch 26/50, Loss: 1.0012
# Epoch 27/50, Loss: 1.0035
# Epoch 28/50, Loss: 0.9852
# Epoch 29/50, Loss: 0.9640
# Epoch 30/50, Loss: 0.9813
# Epoch 31/50, Loss: 0.9825
# Epoch 32/50, Loss: 0.9561
# Epoch 33/50, Loss: 0.9544
# Epoch 34/50, Loss: 0.9374
# Epoch 35/50, Loss: 0.9287
# Epoch 36/50, Loss: 0.9423
# Epoch 37/50, Loss: 0.9042
# Epoch 38/50, Loss: 0.9264
# Epoch 39/50, Loss: 0.9140
# Epoch 40/50, Loss: 0.9212
# Epoch 41/50, Loss: 0.9085
# Epoch 42/50, Loss: 0.8668
# Epoch 43/50, Loss: 0.8879
# Epoch 44/50, Loss: 0.8613
# Epoch 45/50, Loss: 0.8846
# Epoch 46/50, Loss: 0.8986
# Epoch 47/50, Loss: 0.8798
# Epoch 48/50, Loss: 0.8513
# Epoch 49/50, Loss: 0.8814
# Epoch 50/50, Loss: 0.9297
# Test Accuracy: 45.97%
# Accuracy of airplane: 78.10%
# Accuracy of automobile: 60.80%
# Accuracy of bird: 31.90%
# Accuracy of cat: 44.60%
# Accuracy of deer: 27.10%
# Accuracy of dog: 2.90%
# Accuracy of frog: 59.10%
# Accuracy of horse: 55.80%
# Accuracy of ship: 53.70%
# Accuracy of truck: 45.70%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 10] with learning rate: 0.005
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.8034
# Epoch 2/50, Loss: 1.6037
# Epoch 3/50, Loss: 1.5149
# Epoch 4/50, Loss: 1.4485
# Epoch 5/50, Loss: 1.4016
# Epoch 6/50, Loss: 1.3483
# Epoch 7/50, Loss: 1.3052
# Epoch 8/50, Loss: 1.2682
# Epoch 9/50, Loss: 1.2467
# Epoch 10/50, Loss: 1.2224
# Epoch 11/50, Loss: 1.2456
# Epoch 12/50, Loss: 1.1627
# Epoch 13/50, Loss: 1.0998
# Epoch 14/50, Loss: 1.0704
# Epoch 15/50, Loss: 1.0630
# Epoch 16/50, Loss: 1.0283
# Epoch 17/50, Loss: 0.9978
# Epoch 18/50, Loss: 0.9946
# Epoch 19/50, Loss: 0.9610
# Epoch 20/50, Loss: 0.9270
# Epoch 21/50, Loss: 0.9234
# Epoch 22/50, Loss: 0.8778
# Epoch 23/50, Loss: 0.8661
# Epoch 24/50, Loss: 0.8425
# Epoch 25/50, Loss: 0.8624
# Epoch 26/50, Loss: 0.8102
# Epoch 27/50, Loss: 0.8164
# Epoch 28/50, Loss: 0.7913
# Epoch 29/50, Loss: 0.7570
# Epoch 30/50, Loss: 0.8047
# Epoch 31/50, Loss: 0.7611
# Epoch 32/50, Loss: 0.7471
# Epoch 33/50, Loss: 0.7578
# Epoch 34/50, Loss: 0.7132
# Epoch 35/50, Loss: 0.7114
# Epoch 36/50, Loss: 0.6974
# Epoch 37/50, Loss: 0.6741
# Epoch 38/50, Loss: 0.6924
# Epoch 39/50, Loss: 0.6526
# Epoch 40/50, Loss: 0.7791
# Epoch 41/50, Loss: 0.7125
# Epoch 42/50, Loss: 0.6248
# Epoch 43/50, Loss: 0.6374
# Epoch 44/50, Loss: 0.6754
# Epoch 45/50, Loss: 0.6352
# Epoch 46/50, Loss: 0.6321
# Epoch 47/50, Loss: 0.6215
# Epoch 48/50, Loss: 0.6125
# Epoch 49/50, Loss: 0.6256
# Epoch 50/50, Loss: 0.6298
# Test Accuracy: 50.09%
# Accuracy of airplane: 54.30%
# Accuracy of automobile: 65.40%
# Accuracy of bird: 39.70%
# Accuracy of cat: 24.40%
# Accuracy of deer: 37.70%
# Accuracy of dog: 57.80%
# Accuracy of frog: 53.00%
# Accuracy of horse: 48.80%
# Accuracy of ship: 70.90%
# Accuracy of truck: 48.90%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 256, 10] with learning rate: 0.005
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.8086
# Epoch 2/50, Loss: 1.6133
# Epoch 3/50, Loss: 1.5305
# Epoch 4/50, Loss: 1.4742
# Epoch 5/50, Loss: 1.4181
# Epoch 6/50, Loss: 1.3875
# Epoch 7/50, Loss: 1.3592
# Epoch 8/50, Loss: 1.3095
# Epoch 9/50, Loss: 1.3009
# Epoch 10/50, Loss: 1.2598
# Epoch 11/50, Loss: 1.2321
# Epoch 12/50, Loss: 1.2393
# Epoch 13/50, Loss: 1.2240
# Epoch 14/50, Loss: 1.1837
# Epoch 15/50, Loss: 1.2274
# Epoch 16/50, Loss: 1.1634
# Epoch 17/50, Loss: 1.1771
# Epoch 18/50, Loss: 1.1295
# Epoch 19/50, Loss: 1.1022
# Epoch 20/50, Loss: 1.1178
# Epoch 21/50, Loss: 1.0533
# Epoch 22/50, Loss: 1.0600
# Epoch 23/50, Loss: 1.0226
# Epoch 24/50, Loss: 1.0177
# Epoch 25/50, Loss: 0.9966
# Epoch 26/50, Loss: 0.9711
# Epoch 27/50, Loss: 0.9894
# Epoch 28/50, Loss: 1.0391
# Epoch 29/50, Loss: 0.9474
# Epoch 30/50, Loss: 0.9495
# Epoch 31/50, Loss: 0.9482
# Epoch 32/50, Loss: 0.9099
# Epoch 33/50, Loss: 0.9772
# Epoch 34/50, Loss: 0.9207
# Epoch 35/50, Loss: 0.8901
# Epoch 36/50, Loss: 0.9078
# Epoch 37/50, Loss: 0.8955
# Epoch 38/50, Loss: 0.8650
# Epoch 39/50, Loss: 0.8517
# Epoch 40/50, Loss: 0.8501
# Epoch 41/50, Loss: 0.8568
# Epoch 42/50, Loss: 0.8455
# Epoch 43/50, Loss: 0.8323
# Epoch 44/50, Loss: 0.8917
# Epoch 45/50, Loss: 0.8493
# Epoch 46/50, Loss: 0.8882
# Epoch 47/50, Loss: 0.8472
# Epoch 48/50, Loss: 0.7533
# Epoch 49/50, Loss: 0.8068
# Epoch 50/50, Loss: 0.7639
# Test Accuracy: 51.25%
# Accuracy of airplane: 57.40%
# Accuracy of automobile: 64.70%
# Accuracy of bird: 39.30%
# Accuracy of cat: 23.30%
# Accuracy of deer: 39.00%
# Accuracy of dog: 47.90%
# Accuracy of frog: 61.20%
# Accuracy of horse: 54.40%
# Accuracy of ship: 69.20%
# Accuracy of truck: 56.10%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 256, 128, 10] with learning rate: 0.005
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.8156
# Epoch 2/50, Loss: 1.6241
# Epoch 3/50, Loss: 1.5467
# Epoch 4/50, Loss: 1.4815
# Epoch 5/50, Loss: 1.4324
# Epoch 6/50, Loss: 1.4018
# Epoch 7/50, Loss: 1.3568
# Epoch 8/50, Loss: 1.3251
# Epoch 9/50, Loss: 1.2957
# Epoch 10/50, Loss: 1.2602
# Epoch 11/50, Loss: 1.2356
# Epoch 12/50, Loss: 1.2054
# Epoch 13/50, Loss: 1.1791
# Epoch 14/50, Loss: 1.1451
# Epoch 15/50, Loss: 1.1292
# Epoch 16/50, Loss: 1.0894
# Epoch 17/50, Loss: 1.0669
# Epoch 18/50, Loss: 1.0855
# Epoch 19/50, Loss: 1.1040
# Epoch 20/50, Loss: 1.0078
# Epoch 21/50, Loss: 0.9901
# Epoch 22/50, Loss: 0.9779
# Epoch 23/50, Loss: 0.9724
# Epoch 24/50, Loss: 0.9451
# Epoch 25/50, Loss: 0.9320
# Epoch 26/50, Loss: 0.9115
# Epoch 27/50, Loss: 0.8956
# Epoch 28/50, Loss: 0.8748
# Epoch 29/50, Loss: 0.8802
# Epoch 30/50, Loss: 0.8618
# Epoch 31/50, Loss: 0.8307
# Epoch 32/50, Loss: 0.8515
# Epoch 33/50, Loss: 0.8360
# Epoch 34/50, Loss: 0.8090
# Epoch 35/50, Loss: 0.8459
# Epoch 36/50, Loss: 0.8007
# Epoch 37/50, Loss: 0.8534
# Epoch 38/50, Loss: 0.7862
# Epoch 39/50, Loss: 0.7679
# Epoch 40/50, Loss: 0.7623
# Epoch 41/50, Loss: 0.7340
# Epoch 42/50, Loss: 0.7522
# Epoch 43/50, Loss: 0.6973
# Epoch 44/50, Loss: 0.6797
# Epoch 45/50, Loss: 0.7328
# Epoch 46/50, Loss: 0.7112
# Epoch 47/50, Loss: 0.6696
# Epoch 48/50, Loss: 0.7090
# Epoch 49/50, Loss: 0.6779
# Epoch 50/50, Loss: 0.6677
# Test Accuracy: 52.00%
# Accuracy of airplane: 65.00%
# Accuracy of automobile: 61.30%
# Accuracy of bird: 34.90%
# Accuracy of cat: 44.80%
# Accuracy of deer: 45.10%
# Accuracy of dog: 34.30%
# Accuracy of frog: 56.10%
# Accuracy of horse: 55.30%
# Accuracy of ship: 66.50%
# Accuracy of truck: 56.70%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 512, 256, 10] with learning rate: 0.005
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.8368
# Epoch 2/50, Loss: 1.6589
# Epoch 3/50, Loss: 1.5686
# Epoch 4/50, Loss: 1.4961
# Epoch 5/50, Loss: 1.4545
# Epoch 6/50, Loss: 1.4192
# Epoch 7/50, Loss: 1.3843
# Epoch 8/50, Loss: 1.3472
# Epoch 9/50, Loss: 1.3086
# Epoch 10/50, Loss: 1.2950
# Epoch 11/50, Loss: 1.2795
# Epoch 12/50, Loss: 1.2447
# Epoch 13/50, Loss: 1.2167
# Epoch 14/50, Loss: 1.2462
# Epoch 15/50, Loss: 1.1808
# Epoch 16/50, Loss: 1.1730
# Epoch 17/50, Loss: 1.1384
# Epoch 18/50, Loss: 1.1288
# Epoch 19/50, Loss: 1.1078
# Epoch 20/50, Loss: 1.0887
# Epoch 21/50, Loss: 1.0764
# Epoch 22/50, Loss: 1.0466
# Epoch 23/50, Loss: 1.0644
# Epoch 24/50, Loss: 1.0423
# Epoch 25/50, Loss: 1.0144
# Epoch 26/50, Loss: 1.0160
# Epoch 27/50, Loss: 0.9921
# Epoch 28/50, Loss: 0.9614
# Epoch 29/50, Loss: 0.9490
# Epoch 30/50, Loss: 0.9326
# Epoch 31/50, Loss: 0.9069
# Epoch 32/50, Loss: 0.9313
# Epoch 33/50, Loss: 0.9492
# Epoch 34/50, Loss: 0.9601
# Epoch 35/50, Loss: 0.8952
# Epoch 36/50, Loss: 0.8868
# Epoch 37/50, Loss: 0.9035
# Epoch 38/50, Loss: 0.9306
# Epoch 39/50, Loss: 0.9057
# Epoch 40/50, Loss: 0.8444
# Epoch 41/50, Loss: 0.8850
# Epoch 42/50, Loss: 0.8703
# Epoch 43/50, Loss: 0.8431
# Epoch 44/50, Loss: 0.8372
# Epoch 45/50, Loss: 0.8181
# Epoch 46/50, Loss: 0.7922
# Epoch 47/50, Loss: 0.7782
# Epoch 48/50, Loss: 0.8240
# Epoch 49/50, Loss: 0.7890
# Epoch 50/50, Loss: 0.8554
# Test Accuracy: 50.90%
# Accuracy of airplane: 64.60%
# Accuracy of automobile: 57.90%
# Accuracy of bird: 36.10%
# Accuracy of cat: 26.50%
# Accuracy of deer: 39.30%
# Accuracy of dog: 45.00%
# Accuracy of frog: 61.60%
# Accuracy of horse: 59.60%
# Accuracy of ship: 63.00%
# Accuracy of truck: 55.40%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 512, 256, 128, 10] with learning rate: 0.005
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.8935
# Epoch 2/50, Loss: 1.7073
# Epoch 3/50, Loss: 1.6236
# Epoch 4/50, Loss: 1.5536
# Epoch 5/50, Loss: 1.4929
# Epoch 6/50, Loss: 1.4520
# Epoch 7/50, Loss: 1.4100
# Epoch 8/50, Loss: 1.3752
# Epoch 9/50, Loss: 1.3475
# Epoch 10/50, Loss: 1.3164
# Epoch 11/50, Loss: 1.2941
# Epoch 12/50, Loss: 1.2649
# Epoch 13/50, Loss: 1.2369
# Epoch 14/50, Loss: 1.2099
# Epoch 15/50, Loss: 1.1848
# Epoch 16/50, Loss: 1.1549
# Epoch 17/50, Loss: 1.1424
# Epoch 18/50, Loss: 1.1242
# Epoch 19/50, Loss: 1.1160
# Epoch 20/50, Loss: 1.0911
# Epoch 21/50, Loss: 1.0848
# Epoch 22/50, Loss: 1.0352
# Epoch 23/50, Loss: 1.0147
# Epoch 24/50, Loss: 1.0310
# Epoch 25/50, Loss: 1.0364
# Epoch 26/50, Loss: 1.0439
# Epoch 27/50, Loss: 0.9852
# Epoch 28/50, Loss: 1.0242
# Epoch 29/50, Loss: 0.9654
# Epoch 30/50, Loss: 1.0191
# Epoch 31/50, Loss: 1.0085
# Epoch 32/50, Loss: 0.9718
# Epoch 33/50, Loss: 0.9598
# Epoch 34/50, Loss: 0.9697
# Epoch 35/50, Loss: 0.9619
# Epoch 36/50, Loss: 0.9479
# Epoch 37/50, Loss: 0.9612
# Epoch 38/50, Loss: 0.9635
# Epoch 39/50, Loss: 0.9624
# Epoch 40/50, Loss: 0.9265
# Epoch 41/50, Loss: 0.8521
# Epoch 42/50, Loss: 0.8693
# Epoch 43/50, Loss: 1.0613
# Epoch 44/50, Loss: 0.9209
# Epoch 45/50, Loss: 0.8969
# Epoch 46/50, Loss: 1.0292
# Epoch 47/50, Loss: 0.9542
# Epoch 48/50, Loss: 1.0283
# Epoch 49/50, Loss: 0.9133
# Epoch 50/50, Loss: 0.9134
# Test Accuracy: 51.37%
# Accuracy of airplane: 65.30%
# Accuracy of automobile: 65.90%
# Accuracy of bird: 26.40%
# Accuracy of cat: 38.30%
# Accuracy of deer: 39.00%
# Accuracy of dog: 37.80%
# Accuracy of frog: 64.50%
# Accuracy of horse: 57.50%
# Accuracy of ship: 61.40%
# Accuracy of truck: 57.60%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 512, 1024, 512, 256, 10] with learning rate: 0.005
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 1.9445
# Epoch 2/50, Loss: 1.7570
# Epoch 3/50, Loss: 1.6713
# Epoch 4/50, Loss: 1.6243
# Epoch 5/50, Loss: 1.5793
# Epoch 6/50, Loss: 1.5137
# Epoch 7/50, Loss: 1.4681
# Epoch 8/50, Loss: 1.4544
# Epoch 9/50, Loss: 1.4143
# Epoch 10/50, Loss: 1.3815
# Epoch 11/50, Loss: 1.3415
# Epoch 12/50, Loss: 1.3165
# Epoch 13/50, Loss: 1.3003
# Epoch 14/50, Loss: 1.2667
# Epoch 15/50, Loss: 1.2484
# Epoch 16/50, Loss: 1.1971
# Epoch 17/50, Loss: 1.2043
# Epoch 18/50, Loss: 1.2042
# Epoch 19/50, Loss: 1.1519
# Epoch 20/50, Loss: 1.1447
# Epoch 21/50, Loss: 1.1495
# Epoch 22/50, Loss: 1.1461
# Epoch 23/50, Loss: 1.0906
# Epoch 24/50, Loss: 1.0710
# Epoch 25/50, Loss: 1.0466
# Epoch 26/50, Loss: 1.0321
# Epoch 27/50, Loss: 1.0951
# Epoch 28/50, Loss: 1.0289
# Epoch 29/50, Loss: 0.9945
# Epoch 30/50, Loss: 1.0306
# Epoch 31/50, Loss: 1.0686
# Epoch 32/50, Loss: 1.0177
# Epoch 33/50, Loss: 1.0051
# Epoch 34/50, Loss: 1.0966
# Epoch 35/50, Loss: 1.0482
# Epoch 36/50, Loss: 0.9612
# Epoch 37/50, Loss: 0.9489
# Epoch 38/50, Loss: 0.9651
# Epoch 39/50, Loss: 0.9416
# Epoch 40/50, Loss: 0.9199
# Epoch 41/50, Loss: 0.9503
# Epoch 42/50, Loss: 0.9829
# Epoch 43/50, Loss: 0.9227
# Epoch 44/50, Loss: 0.8640
# Epoch 45/50, Loss: 0.8568
# Epoch 46/50, Loss: 0.8550
# Epoch 47/50, Loss: 0.8463
# Epoch 48/50, Loss: 0.9340
# Epoch 49/50, Loss: 0.9430
# Epoch 50/50, Loss: 0.8686
# Test Accuracy: 51.32%
# Accuracy of airplane: 69.00%
# Accuracy of automobile: 64.00%
# Accuracy of bird: 34.60%
# Accuracy of cat: 33.80%
# Accuracy of deer: 42.60%
# Accuracy of dog: 41.50%
# Accuracy of frog: 54.10%
# Accuracy of horse: 55.60%
# Accuracy of ship: 61.20%
# Accuracy of truck: 56.80%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 512, 1024, 512, 256, 128, 10] with learning rate: 0.005
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 2.0337
# Epoch 2/50, Loss: 1.9137
# Epoch 3/50, Loss: 1.8670
# Epoch 4/50, Loss: 1.8025
# Epoch 5/50, Loss: 1.7896
# Epoch 6/50, Loss: 1.7898
# Epoch 7/50, Loss: 1.7794
# Epoch 8/50, Loss: 1.7713
# Epoch 9/50, Loss: 1.7473
# Epoch 10/50, Loss: 1.7655
# Epoch 11/50, Loss: 1.7659
# Epoch 12/50, Loss: 1.7710
# Epoch 13/50, Loss: 1.7675
# Epoch 14/50, Loss: 1.7782
# Epoch 15/50, Loss: 1.7538
# Epoch 16/50, Loss: 1.7317
# Epoch 17/50, Loss: 1.7443
# Epoch 18/50, Loss: 1.7057
# Epoch 19/50, Loss: 1.7028
# Epoch 20/50, Loss: 1.7200
# Epoch 21/50, Loss: 1.7358
# Epoch 22/50, Loss: 1.7093
# Epoch 23/50, Loss: 1.7167
# Epoch 24/50, Loss: 1.7445
# Epoch 25/50, Loss: 1.7187
# Epoch 26/50, Loss: 1.7508
# Epoch 27/50, Loss: 1.7642
# Epoch 28/50, Loss: 1.8218
# Epoch 29/50, Loss: 1.7371
# Epoch 30/50, Loss: 1.7786
# Epoch 31/50, Loss: 1.7131
# Epoch 32/50, Loss: 1.7273
# Epoch 33/50, Loss: 1.7399
# Epoch 34/50, Loss: 1.6950
# Epoch 35/50, Loss: 1.6930
# Epoch 36/50, Loss: 1.8475
# Epoch 37/50, Loss: 1.7324
# Epoch 38/50, Loss: 1.6941
# Epoch 39/50, Loss: 1.7830
# Epoch 40/50, Loss: 1.7783
# Epoch 41/50, Loss: 1.7656
# Epoch 42/50, Loss: 1.7090
# Epoch 43/50, Loss: 1.7599
# Epoch 44/50, Loss: 1.8125
# Epoch 45/50, Loss: 1.8320
# Epoch 46/50, Loss: 1.7858
# Epoch 47/50, Loss: 1.7686
# Epoch 48/50, Loss: 1.7143
# Epoch 49/50, Loss: 1.7003
# Epoch 50/50, Loss: 1.6799
# Test Accuracy: 35.46%
# Accuracy of airplane: 37.00%
# Accuracy of automobile: 65.60%
# Accuracy of bird: 21.40%
# Accuracy of cat: 21.10%
# Accuracy of deer: 9.90%
# Accuracy of dog: 20.20%
# Accuracy of frog: 44.70%
# Accuracy of horse: 56.40%
# Accuracy of ship: 64.90%
# Accuracy of truck: 13.40%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 512, 1024, 2048, 1024, 512, 256, 128, 10] with learning rate: 0.005
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 2.0424
# Epoch 2/50, Loss: 2.1614
# Epoch 3/50, Loss: 1.9574
# Epoch 4/50, Loss: 1.9439
# Epoch 5/50, Loss: 1.9125
# Epoch 6/50, Loss: 1.8699
# Epoch 7/50, Loss: 1.8475
# Epoch 8/50, Loss: 1.8473
# Epoch 9/50, Loss: 1.8493
# Epoch 10/50, Loss: 1.8102
# Epoch 11/50, Loss: 1.7660
# Epoch 12/50, Loss: 1.7830
# Epoch 13/50, Loss: 1.7314
# Epoch 14/50, Loss: 1.7315
# Epoch 15/50, Loss: 1.9478
# Epoch 16/50, Loss: 1.8133
# Epoch 17/50, Loss: 1.8051
# Epoch 18/50, Loss: 1.7952
# Epoch 19/50, Loss: 1.7798
# Epoch 20/50, Loss: 1.8020
# Epoch 21/50, Loss: 1.7407
# Epoch 22/50, Loss: 1.9899
# Epoch 23/50, Loss: 1.8167
# Epoch 24/50, Loss: 1.7372
# Epoch 25/50, Loss: nan
# Epoch 26/50, Loss: nan
# Epoch 27/50, Loss: nan
# Epoch 28/50, Loss: nan
# Epoch 29/50, Loss: nan
# Epoch 30/50, Loss: nan
# Epoch 31/50, Loss: nan
# Epoch 32/50, Loss: nan
# Epoch 33/50, Loss: nan
# Epoch 34/50, Loss: nan
# Epoch 35/50, Loss: nan
# Epoch 36/50, Loss: nan
# Epoch 37/50, Loss: nan
# Epoch 38/50, Loss: nan
# Epoch 39/50, Loss: nan
# Epoch 40/50, Loss: nan
# Epoch 41/50, Loss: nan
# Epoch 42/50, Loss: nan
# Epoch 43/50, Loss: nan
# Epoch 44/50, Loss: nan
# Epoch 45/50, Loss: nan
# Epoch 46/50, Loss: nan
# Epoch 47/50, Loss: nan
# Epoch 48/50, Loss: nan
# Epoch 49/50, Loss: nan
# Epoch 50/50, Loss: nan
# Test Accuracy: 10.00%
# Accuracy of airplane: 100.00%
# Accuracy of automobile: 0.00%
# Accuracy of bird: 0.00%
# Accuracy of cat: 0.00%
# Accuracy of deer: 0.00%
# Accuracy of dog: 0.00%
# Accuracy of frog: 0.00%
# Accuracy of horse: 0.00%
# Accuracy of ship: 0.00%
# Accuracy of truck: 0.00%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Training topology: [1024, 128, 256, 512, 1024, 512, 1024, 256, 128, 10] with learning rate: 0.005
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 1/50, Loss: 2.0604
# Epoch 2/50, Loss: 1.9631
# Epoch 3/50, Loss: 1.9456
# Epoch 4/50, Loss: 1.8461
# Epoch 5/50, Loss: 1.8655
# Epoch 6/50, Loss: 1.7583
# Epoch 7/50, Loss: 1.6828
# Epoch 8/50, Loss: 1.6186
# Epoch 9/50, Loss: 1.5665
# Epoch 10/50, Loss: 1.5443
# Epoch 11/50, Loss: 1.5193
# Epoch 12/50, Loss: 1.4924
# Epoch 13/50, Loss: 1.4808
# Epoch 14/50, Loss: 1.4581
# Epoch 15/50, Loss: 1.4441
# Epoch 16/50, Loss: 1.4421
# Epoch 17/50, Loss: 1.4934
# Epoch 18/50, Loss: 1.5152
# Epoch 19/50, Loss: 1.4473
# Epoch 20/50, Loss: 1.3888
# Epoch 21/50, Loss: 1.3640
# Epoch 22/50, Loss: 1.3596
# Epoch 23/50, Loss: 1.3549
# Epoch 24/50, Loss: 1.3446
# Epoch 25/50, Loss: 1.3522
# Epoch 26/50, Loss: 1.3381
# Epoch 27/50, Loss: 1.3067
# Epoch 28/50, Loss: 1.3091
# Epoch 29/50, Loss: 1.2975
# Epoch 30/50, Loss: 1.2710
# Epoch 31/50, Loss: 1.2922
# Epoch 32/50, Loss: 1.2683
# Epoch 33/50, Loss: 1.2820
# Epoch 34/50, Loss: 1.2319
# Epoch 35/50, Loss: 1.3302
# Epoch 36/50, Loss: 1.2810
# Epoch 37/50, Loss: 1.3122
# Epoch 38/50, Loss: 1.2210
# Epoch 39/50, Loss: 1.2131
# Epoch 40/50, Loss: 1.2214
# Epoch 41/50, Loss: 1.2783
# Epoch 42/50, Loss: 1.2991
# Epoch 43/50, Loss: 1.2591
# Epoch 44/50, Loss: 1.2331
# Epoch 45/50, Loss: 1.2471
# Epoch 46/50, Loss: nan
# Epoch 47/50, Loss: nan
# Epoch 48/50, Loss: 1.4844
# Epoch 49/50, Loss: 1.4154
# Epoch 50/50, Loss: 1.3006
# Test Accuracy: 45.74%
# Accuracy of airplane: 62.80%
# Accuracy of automobile: 52.20%
# Accuracy of bird: 4.60%
# Accuracy of cat: 12.10%
# Accuracy of deer: 48.50%
# Accuracy of dog: 52.70%
# Accuracy of frog: 49.60%
# Accuracy of horse: 58.10%
# Accuracy of ship: 63.00%
# Accuracy of truck: 53.80%
# Saved images to 'output/true' (correct) and 'output/false' (incorrect')
# Zipped folder 'output' into 'output.zip'
